# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
worldHappiness19 = pd.read_csv("2019.csv")
worldHappiness18 = pd.read_csv("2018.csv")
worldHappiness17 = pd.read_csv("2017.csv")
worldHappiness16 = pd.read_csv("2016.csv")
worldHappiness15 = pd.read_csv("2015.csv")

worldHappiness19["Year"] = 2019
worldHappiness18["Year"] = 2018
worldHappiness17["Year"] = 2017
worldHappiness16["Year"] = 2016
worldHappiness15["Year"] = 2015

worldHappiness1516 = [worldHappiness15, worldHappiness16]
worldHappiness1516 = pd.concat(worldHappiness1516)

worldHappiness1516.drop(columns=["Region", "Standard Error", "Dystopia Residual","Family",
                                 'Lower Confidence Interval','Upper Confidence Interval', 'Happiness Rank'], inplace=True)

worldHappiness1516.rename(columns = {'Happiness Score':'Score', 'Economy (GDP per Capita)':'GDP per capita',
                                    'Trust (Government Corruption)':'Perceptions of corruption', 
                                     'Health (Life Expectancy)':'Healthy life expectancy',
                                    'Country':'Country or region'}, inplace = True)


worldHappiness1819 = [worldHappiness18,worldHappiness19]
worldHappiness1819 = pd.concat(worldHappiness1819)
worldHappiness1819.drop(columns = ['Overall rank','Social support'])
worldHappiness1819.rename(columns = {'Freedom to make life choices' : 'Freedom'}, inplace=True)

worldHappiness17.drop(columns = ['Happiness.Rank','Whisker.high','Whisker.low','Family', 'Dystopia.Residual'], inplace=True)
worldHappiness17.rename(columns = {'Happiness.Score' : 'Score', 'Economy..GDP.per.Capita.' : 'GDP per capita',
                                  'Health..Life.Expectancy.' : 'Healthy life expectancy',
                                   'Trust..Government.Corruption.' : 'Perceptions of corruption', 
                                   'Country':'Country or region'}, inplace=True)

worldHappiness = [worldHappiness1516, worldHappiness17, worldHappiness1819]
worldHappiness = pd.concat(worldHappiness)

worldHappiness.drop(columns = ['Overall rank', 'Social support'], inplace=True)

worldHappiness.head(160)
# Out:
#     Country or region  Score  GDP per capita  Healthy life expectancy  \
# 0         Switzerland  7.587         1.39651                  0.94143
# 1             Iceland  7.561         1.30232                  0.94784
# 2             Denmark  7.527         1.32548                  0.87464
# 3              Norway  7.522         1.45900                  0.88521
# 4              Canada  7.427         1.32629                  0.90563
# ..                ...    ...             ...                      ...
# 155             Syria  3.006         0.66320                  0.72193
# 156           Burundi  2.905         0.01530                  0.22396
# 157              Togo  2.839         0.20868                  0.28443
# 0             Denmark  7.526         1.44178                  0.79504
# 1         Switzerland  7.509         1.52733                  0.86303
#
#      Freedom  Perceptions of corruption  Generosity  Year
# 0    0.66557                    0.41978     0.29678  2015
# 1    0.62877                    0.14145     0.43630  2015
# 2    0.64938                    0.48357     0.34139  2015
# 3    0.66973                    0.36503     0.34699  2015
# 4    0.63297                    0.32957     0.45811  2015
# ..       ...                        ...         ...   ...
# 155  0.15684                    0.18906     0.47179  2015
# 156  0.11850                    0.10062     0.19727  2015
# 157  0.36453                    0.10731     0.16681  2015
# 0    0.57941                    0.44453     0.36171  2016
# 1    0.58557                    0.41203     0.28083  2016
#
# [160 rows x 8 columns]

# %%
worldHappiness19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  Year
# 0                      0.393  2019
# 1                      0.410  2019
# 2                      0.341  2019
# 3                      0.118  2019
# 4                      0.298  2019

# %% [markdown]
# <p>This table above shows us the top 5 happiest countries according to the 2019 world happiness report (all Scandanavian).</p>

# %%
worldHappiness19.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption  Year
# 151       0.217                      0.411  2019
# 152       0.276                      0.147  2019
# 153       0.158                      0.025  2019
# 154       0.235                      0.035  2019
# 155       0.202                      0.091  2019

# %% [markdown]
# <p>The above table shows us the 5 least happy countries, from the same source (all third world countries).</p>

# %%
versus1819 = worldHappiness19.compare(worldHappiness18, align_axis = 'rows')
versus1819.head(10)
# Out:
#         Country or region  Score  GDP per capita  Social support  \
# 0 self                NaN  7.769           1.340           1.587
#   other               NaN  7.632           1.305           1.592
# 1 self            Denmark  7.600           1.383           1.573
#   other            Norway  7.594           1.456           1.582
# 2 self             Norway  7.554           1.488           1.582
#   other           Denmark  7.555           1.351           1.590
# 3 self                NaN  7.494           1.380           1.624
#   other               NaN  7.495           1.343           1.644
# 4 self        Netherlands  7.488           1.396           1.522
#   other       Switzerland  7.487           1.420           1.549
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0 self                     0.986                         0.596       0.153
#   other                    0.874                         0.681       0.202
# 1 self                     0.996                         0.592       0.252
#   other                    0.861                         0.686       0.286
# 2 self                     1.028                         0.603       0.271
#   other                    0.868                         0.683       0.284
# 3 self                     1.026                         0.591       0.354
#   other                    0.914                         0.677       0.353
# 4 self                     0.999                         0.557       0.322
#   other                    0.927                         0.660       0.256
#
#          Perceptions of corruption  Year
# 0 self                         NaN  2019
#   other                        NaN  2018
# 1 self                       0.410  2019
#   other                      0.340  2018
# 2 self                       0.341  2019
#   other                      0.408  2018
# 3 self                       0.118  2019
#   other                      0.138  2018
# 4 self                       0.298  2019
#   other                      0.357  2018

# %% [markdown]
# <p>The above table compares the top five happiest countries in 2019 and 2018. Self is 2019 and Other is 2018. As we can, see, Norway and Denmark switched spots, while Finland and Iceland retained their spots. Switzerland lost its spot to the Netherlands. It's interesting to see that the happiest ccountries are Scandanavian countries.</p>

# %%
versus1819.tail(10)
# Out:
#           Country or region  Score  GDP per capita  Social support  \
# 151 self             Rwanda  3.334           0.359           0.711
#     other             Yemen  3.355           0.442           1.073
# 152 self                NaN  3.231           0.476           0.885
#     other               NaN  3.303           0.455           0.991
# 153 self        Afghanistan  3.203           0.350           0.517
#     other       South Sudan  3.254           0.337           0.608
# 154 self                NaN    NaN           0.026             NaN
#     other               NaN    NaN           0.024             NaN
# 155 self        South Sudan  2.853           0.306           0.575
#     other           Burundi  2.905           0.091           0.627
#
#            Healthy life expectancy  Freedom to make life choices  Generosity  \
# 151 self                     0.614                         0.555       0.217
#     other                    0.343                         0.244       0.083
# 152 self                     0.499                         0.417       0.276
#     other                    0.381                         0.481       0.270
# 153 self                     0.361                         0.000       0.158
#     other                    0.177                         0.112       0.224
# 154 self                     0.105                         0.225       0.235
#     other                    0.010                         0.305       0.218
# 155 self                     0.295                         0.010       0.202
#     other                    0.145                         0.065       0.149
#
#            Perceptions of corruption  Year
# 151 self                       0.411  2019
#     other                      0.064  2018
# 152 self                       0.147  2019
#     other                      0.097  2018
# 153 self                       0.025  2019
#     other                      0.106  2018
# 154 self                       0.035  2019
#     other                      0.038  2018
# 155 self                       0.091  2019
#     other                      0.076  2018

# %% [markdown]
# <p>The table above compares the top five least happy countries in 2019 and 2018. Self is 2019 and Other is 2018. South Sudan made a huge drop of two places, replacing Burundi as least happy country, while Burundi made a huge leap in happiness, not even visible in this list. Tanzania and Central African Republic retained their places.</p>

# %%
plothing = plt.scatter('Healthy life expectancy','Score', data=worldHappiness19)
plt.plot(np.unique(worldHappiness19['Healthy life expectancy']), np.poly1d(np.polyfit(worldHappiness19['Healthy life expectancy'], worldHappiness19['Score'], 1))(np.unique(worldHappiness19['Healthy life expectancy'])))
plt.xlabel("Healthy Life Expectancy")
plt.ylabel("Happiness")
plt.show()

# %% [markdown]
# <h1>Healthy Life Expectancy vs Happiness</h1>
# <p>This graph correlates Healthy Life Expectancy with Happiness. Healthy Life Expectancy differs from life expecancy in that it predicts years lived with health, and not total years lived.
#
# As we can see, there is a strong correlation. As life expectancy increases, so does happiness. This <em>implies </em> causation, although it most definitely does not confirm causation. It could just mean that greater healthy life expectancy is due to greater safety and medical care which would make people happy, and not just that living longer makes people happier. However, the data does seem to back up the saying "Health is Wealth".</p>

# %%
plothing = plt.scatter('Freedom to make life choices','Score', data=worldHappiness19)
plt.plot(np.unique(worldHappiness19['Freedom to make life choices']), np.poly1d(np.polyfit(worldHappiness19['Freedom to make life choices'], worldHappiness19['Score'], 1))(np.unique(worldHappiness19['Freedom to make life choices'])))
plt.xlabel("Freedom")
plt.ylabel("Happiness")
plt.show()

# %% [markdown]
# <h1>Freedom vs Happiness</h1>
# <p>This graph correlates Freedom with Happiness. As we can see, there is a visible trend, although it is interesting to note that it is less strongly correlated with happiness than life expectancy. The slope is much less steep. This implies, although once again, does not confirm, that longevity is more important to happiness than freedom.</p>

# %%
plothing = plt.scatter('Perceptions of corruption','Score', data=worldHappiness19)
plt.plot(np.unique(worldHappiness19['Perceptions of corruption']), np.poly1d(np.polyfit(worldHappiness19['Perceptions of corruption'], worldHappiness19['Score'], 1))(np.unique(worldHappiness19['Perceptions of corruption'])))
plt.xlabel("Percieved Corruption")
plt.ylabel("Happiness")
plt.show()

# %% [markdown]
# <h1>Percieved Corruption vs Happiness</h1>
# <h3>Please remember that this is <em>percieved</em> corruption, and is not the legitimate amount of corruption, just what is percieved by the people.</h3>
#
# <p>It is extremely interesting to see that there is pretty much zero trend in this graph, implying that corruption doesn't really have an effect on happiness.
#
# My guess for the huge blob in the left is that there were so many countries that were voted as having low corruption, that all of them had differing values for all the other factors, leadding to the widely varying happiness scores for the same amount of percieved corruption.
#
# What is even more interesting to note, however, is that there is a very small amount of countries with percieved corruption higher than 0.2, and they all have extremely high happiness scores. </p>

# %%
plothing = plt.scatter('GDP per capita','Score', data=worldHappiness19)
plt.plot(np.unique(worldHappiness19['GDP per capita']), np.poly1d(np.polyfit(worldHappiness19['GDP per capita'], worldHappiness19['Score'], 1))(np.unique(worldHappiness19['GDP per capita'])))
plt.xlabel("GDP")
plt.ylabel("Happiness")
plt.show()

# %% [markdown]
# <h1>GDP vs Happiness</h1>
# <p>There is a very obvious trend in this graph, although not <em>as</em> clear as the Health vs Happiness graph. The data seems to be implying that wealth is very important to happiness, although there are a few outliers.</p>

# %%
plothing = plt.scatter('Generosity','Score', data=worldHappiness19)
plt.plot(np.unique(worldHappiness19['Generosity']), np.poly1d(np.polyfit(worldHappiness19['Generosity'], worldHappiness19['Score'], 1))(np.unique(worldHappiness19['Generosity'])))
plt.xlabel("Generosity")
plt.ylabel("Happiness")
plt.show()

# %% [markdown]
# <h1>Generosity vs Happiness</h1>
# <p>It is very interesting to see that there is very little trend in this graph. Also interesting, however, is how most countries appear to be clumped around 0.1 - 0.2 Generosity, with a few outliers. These outliers that have 0.4 - 0.5 generosity, are actually <em>less</em> happy. I believe we can safely assume that Generosity is irrelevant to Happiness.</p>

# %%
plothing = plt.scatter('GDP per capita','Generosity', data=worldHappiness19)
plt.plot(np.unique(worldHappiness19['GDP per capita']), np.poly1d(np.polyfit(worldHappiness19['GDP per capita'], worldHappiness19['Generosity'], 1))(np.unique(worldHappiness19['GDP per capita'])))
plt.xlabel("GDP")
plt.ylabel("Generosity")
plt.show()

# %% [markdown]
# <h1>GDP vs Generosity</h1>
# <p>While the general trend is down (and isn't that sad to see), the slope is not significant, and it appears that there is little to no correlation between GDP and Generosity. It appears that no matter the country's GDP, Generosity remains mostly the same.</p>

# %%
plothing = plt.scatter('GDP per capita','Healthy life expectancy', data=worldHappiness19)
plt.plot(np.unique(worldHappiness19['GDP per capita']), np.poly1d(np.polyfit(worldHappiness19['GDP per capita'], worldHappiness19['Healthy life expectancy'], 1))(np.unique(worldHappiness19['GDP per capita'])))
plt.xlabel("GDP")
plt.ylabel("Healthy life expectancy")
plt.show()

# %% [markdown]
# <h1>GDP vs Healthy Life Expectancy</h1>
# <p>There is a very strong correlation in this graph, which might be because in general, countries with higher GDP have better healthcare. This might be why GDP and happiness are correlated, and might mean that we don't even need wealth, just <strong>HEALTH</strong>.</p>

# %%
happiness = []
happiness.append(worldHappiness15['Happiness Score'].mean())
happiness.append(worldHappiness16['Happiness Score'].mean())
happiness.append(worldHappiness17['Score'].mean())
happiness.append(worldHappiness18['Score'].mean())
happiness.append(worldHappiness19['Score'].mean())

happyData = {'Year':  [2015, 2016, 2017, 2018, 2019],
        'Average Happiness': happiness
        }

happyDataFrame = pd.DataFrame (happyData, columns = ['Year','Average Happiness'])

happyDataFrame.head()
# Out:
#    Year  Average Happiness
# 0  2015           5.375734
# 1  2016           5.382185
# 2  2017           5.354019
# 3  2018           5.375917
# 4  2019           5.407096

# %%
plothing = plt.scatter('Year','Average Happiness', data=happyDataFrame)
plt.plot(np.unique(happyDataFrame['Year']), np.poly1d(np.polyfit(happyDataFrame['Year'], happyDataFrame['Average Happiness'], 1))(np.unique(happyDataFrame['Year'])))
plt.xlabel("Year")
plt.ylabel("Happiness Average")
plt.show()

# %% [markdown]
# <h1>Year vs Average Happiness</h1>
#
# <p>Since we don't have much data - only five years worth, the graph is pretty pointless, and there is no visible trend, but it is interesting to see that there is a positive slope, although, looking at the y-axis, the slope <em>is</em> minute. Also, it's interesting to see that 2019 was our happiest year yet!</p>

# %% [markdown]
# <h1>Conclusion</h1>
# <p>In conclusion, Healthy Life Expectancy seems to be most important to Happiness, followed by GDP per capita, and then Freedom. Percieved Corruption seems to be irrelevant, as does Generosity. The data appears to be implying that <strong>HEALTH and WEALTH</strong> are most important to us for our happiness.
#
# It could also be that <strong>HEALTH</strong> is most important to our happiness, and a higher GDP just means that we can afford better healthcare.
#
# Since, as we noted earlier, Scandanavian countries are happier countries, we can guess that the reason for this is that they have a high GDP, and high Healthy Life Expectancy (double checked below). This also explains why the least happy countries are third world countries. Third world countries have low healthy life expectancy and also low GDP. Since these two factors appear to be most important to happiness, it makes sense that these countries wouldn't rank as highly in happiness.
#
# Generosity is not related to GDP per capita. Most countries, regardless of GDP, are equally generous.
#
# Happiness appears to have gone up over the past couple of years, with a crash in 2017. 2019 was our happiest year recorded.</p>

# %%
scandanavianScore = worldHappiness19.loc[0:4,["Country or region", "Score", "GDP per capita", "Healthy life expectancy"]]
scandanavianScore
# Out:
#   Country or region  Score  GDP per capita  Healthy life expectancy
# 0           Finland  7.769           1.340                    0.986
# 1           Denmark  7.600           1.383                    0.996
# 2            Norway  7.554           1.488                    1.028
# 3           Iceland  7.494           1.380                    1.026
# 4       Netherlands  7.488           1.396                    0.999

# %%
import folium
world = folium.Map(location=[0,0], zoom_start=2)
happyMap = '2019.csv'
wc = 'world_countries.json'
world.choropleth(geo_data=wc,
                data=worldHappiness19,
                columns=['Country or region', 'Score'],
                key_on='feature.properties.name',
                fill_color='YlGnBu',
                fill_opacity=0.9,
                line_opacity=0.3,
                legend_name='Happiness Levels'
                )
world
# Out:
# C:\Users\sipra\miniconda3\envs\pythonthing\lib\site-packages\folium\folium.py:411: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e0942c9266a441bab3afec84d79180cb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e0942c9266a441bab3afec84d79180cb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e0942c9266a441bab3afec84d79180cb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e0942c9266a441bab3afec84d79180cb%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# The map above displays happiness levels per country. The darker the color, the happier the nation, but black means that there was no data.

# %%
world = folium.Map(location=[0,0], zoom_start=2)
happyMap = '2019.csv'
wc = 'world_countries.json'
world.choropleth(geo_data=wc,
                data=worldHappiness19,
                columns=['Country or region', 'Healthy life expectancy'],
                key_on='feature.properties.name',
                fill_color='YlGnBu',
                fill_opacity=0.9,
                line_opacity=0.3,
                legend_name='Healthy Life Expectancy'
                )
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b4db474088084b5abeca77fa26a1e4f8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b4db474088084b5abeca77fa26a1e4f8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b4db474088084b5abeca77fa26a1e4f8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b4db474088084b5abeca77fa26a1e4f8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <p>This map looks extremely similar to the one above, and displays healthy life expectancy per country. As demonstrated earlier, many of the happier countries also have better health.</p>

# %%
import folium
world = folium.Map(location=[0,0], zoom_start=2)
happyMap = '2019.csv'
wc = 'world_countries.json'
world.choropleth(geo_data=wc,
                data=worldHappiness19,
                columns=['Country or region', 'GDP per capita'],
                key_on='feature.properties.name',
                fill_color='YlGnBu',
                fill_opacity=0.9,
                line_opacity=0.3,
                legend_name='GDP per capita'
                )
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dc48248fbb5947f18b694269c5886154%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dc48248fbb5947f18b694269c5886154%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dc48248fbb5947f18b694269c5886154%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dc48248fbb5947f18b694269c5886154%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# This map (showing GDP) is also similar to the happiness map, but definitely not as close as the Healthy Life Expectancy map.
